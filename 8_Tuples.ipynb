# %% [markdown]
# <a href="https://colab.research.google.com/github/bttrung/python-study/blob/master/8_Tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tuples = a data type for immutable ordered sequence of element
# Tuples is similar to list, but immutable
days = ('Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun')

# %%
days[0]
# Out:
# 'Mon'

# %%
days[-1]
# Out:
# 'Sun'

# %%
days[2:5]
# Out:
# ('Wed', 'Thu', 'Fri')

# %%
# Tuples is immutable
days[2]='New'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-8bd8b1dde524> in <module>()
# ----> 1 days[2]='New'
#
# TypeError: 'tuple' object does not support item assignment

# %%
# another way to create tuples
tuples_1 = 1, 2, 3
tuples_2 = 1, 2, 3

# %%
tuples_1
# Out:
# (1, 2, 3)

# %%
tuples_2
# Out:
# (1, 2, 3)

# %%
tuples_1 == tuples_2
# Out:
# True

# %%
type(tuples_1)
# Out:
# tuple
