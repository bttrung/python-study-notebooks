# %% [markdown]
# <a href="https://colab.research.google.com/github/bttrung/python-study-notebooks/blob/master/pandas/7_Loading_Data_into_a_Pandas_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
gs = pd.read_csv('./GOOG.csv')
gs
# Out:
#            Date         Open         High  ...        Close    Adj Close   Volume
# 0    2018-09-18  1157.089966  1176.079956  ...  1161.219971  1161.219971  1203600
# 1    2018-09-19  1164.979980  1173.209961  ...  1171.089966  1171.089966  1191400
# 2    2018-09-20  1179.989990  1189.890015  ...  1186.869995  1186.869995  1225400
# 3    2018-09-21  1192.000000  1192.209961  ...  1166.089966  1166.089966  4405600
# 4    2018-09-24  1157.170044  1178.000000  ...  1173.369995  1173.369995  1271000
# 5    2018-09-25  1176.150024  1186.880005  ...  1184.650024  1184.650024   977700
# 6    2018-09-26  1185.150024  1194.229980  ...  1180.489990  1180.489990  1462300
# 7    2018-09-27  1186.729980  1202.099976  ...  1194.640015  1194.640015  1260800
# 8    2018-09-28  1191.869995  1195.410034  ...  1193.469971  1193.469971  1380600
# 9    2018-10-01  1199.890015  1209.900024  ...  1195.310059  1195.310059  1357600
# ...

# %%
type(gs)
# Out:
# pandas.core.frame.DataFrame

# %%
gs.shape
# Out:
# (252, 7)

# %%
# just see some 1st rows
gs.head()
# Out:
#          Date         Open         High  ...        Close    Adj Close   Volume
# 0  2018-09-18  1157.089966  1176.079956  ...  1161.219971  1161.219971  1203600
# 1  2018-09-19  1164.979980  1173.209961  ...  1171.089966  1171.089966  1191400
# 2  2018-09-20  1179.989990  1189.890015  ...  1186.869995  1186.869995  1225400
# 3  2018-09-21  1192.000000  1192.209961  ...  1166.089966  1166.089966  4405600
# 4  2018-09-24  1157.170044  1178.000000  ...  1173.369995  1173.369995  1271000
#
# [5 rows x 7 columns]

# %%
# see 2 1st row
gs.head(2)
# Out:
#          Date         Open         High  ...        Close    Adj Close   Volume
# 0  2018-09-18  1157.089966  1176.079956  ...  1161.219971  1161.219971  1203600
# 1  2018-09-19  1164.979980  1173.209961  ...  1171.089966  1171.089966  1191400
#
# [2 rows x 7 columns]

# %%
# see some last row
gs.tail()
# Out:
#            Date         Open         High  ...        Close    Adj Close   Volume
# 247  2019-09-12  1224.300049  1241.859985  ...  1234.250000  1234.250000  1725900
# 248  2019-09-13  1231.349976  1240.880005  ...  1239.560059  1239.560059  1301400
# 249  2019-09-16  1229.520020  1239.560059  ...  1231.300049  1231.300049  1053300
# 250  2019-09-17  1230.400024  1235.000000  ...  1229.150024  1229.150024   955100
# 251  2019-09-18  1227.510010  1230.500000  ...  1227.839966  1227.839966   268454
#
# [5 rows x 7 columns]

# %%
# see 3 last row
gs.tail(3)
# Out:
#            Date         Open         High  ...        Close    Adj Close   Volume
# 249  2019-09-16  1229.520020  1239.560059  ...  1231.300049  1231.300049  1053300
# 250  2019-09-17  1230.400024  1235.000000  ...  1229.150024  1229.150024   955100
# 251  2019-09-18  1227.510010  1230.500000  ...  1227.839966  1227.839966   268454
#
# [3 rows x 7 columns]

# %%
# check if are there null value in any column
gs.isnull().any()
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %%
# get descriptive statistics on our stock data
gs.describe()
# Out:
#               Open         High  ...    Adj Close        Volume
# count   252.000000   252.000000  ...   252.000000  2.520000e+02
# mean   1130.893037  1142.145173  ...  1131.249205  1.597599e+06
# std      62.873521    60.768924  ...    64.004900  7.388059e+05
# min     973.900024  1003.539978  ...   976.219971  2.684540e+05
# 25%    1079.867493  1092.682464  ...  1079.680023  1.190400e+06
# 50%    1130.579956  1141.875000  ...  1132.075012  1.436500e+06
# 75%    1182.947479  1193.127533  ...  1184.499970  1.817200e+06
# max    1274.000000  1289.270020  ...  1287.579956  6.207000e+06
#
# [8 rows x 6 columns]

# %%
gs.max()
# Out:
# Date         2019-09-18
# Open               1274
# High            1289.27
# Low              1266.3
# Close           1287.58
# Adj Close       1287.58
# Volume          6207000
# dtype: object

# %%
gs.min()
# Out:
# Date         2018-09-18
# Open              973.9
# High            1003.54
# Low              970.11
# Close            976.22
# Adj Close        976.22
# Volume           268454
# dtype: object

# %%
gs.mean()
# Out:
# Open         1.130893e+03
# High         1.142145e+03
# Low          1.119721e+03
# Close        1.131249e+03
# Adj Close    1.131249e+03
# Volume       1.597599e+06
# dtype: float64

# %%
gs.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.986855  0.985973  0.970235   0.970235 -0.258216
# High       0.986855  1.000000  0.984660  0.986068   0.986068 -0.211892
# Low        0.985973  0.984660  1.000000  0.989582   0.989582 -0.308489
# Close      0.970235  0.986068  0.989582  1.000000   1.000000 -0.268072
# Adj Close  0.970235  0.986068  0.989582  1.000000   1.000000 -0.268072
# Volume    -0.258216 -0.211892 -0.308489 -0.268072  -0.268072  1.000000

# %% [markdown]
# ## Group By

# %%
data = pd.read_csv('./fake_company.csv')
data
# Out:
#    Year     Name Department  Age  Salary\t
# 0  1990    Alice         HR   25     50000
# 1  1990      Bob         RD   30     48000
# 2  1990  Charlie      Admin   45     55000
# 3  1991    Alice         HR   26     52000
# 4  1991      Bob         RD   31     50000
# 5  1991  Charlie      Admin   46     60000
# 6  1992    Alice         HR   27     60000
# 7  1992      Bob         RD   32     52000
# 8  1992  Charlie      Admin   47     62000

# %%
data.groupby(['Year'])['Age'].sum()
# Out:
# Year
# 1990    100
# 1991    103
# 1992    106
# Name: Age, dtype: int64

# %%
data.groupby(['Year'])['Age'].mean()
# Out:
# Year
# 1990    33.333333
# 1991    34.333333
# 1992    35.333333
# Name: Age, dtype: float64

# %%
data.groupby(['Name'])['Age'].sum()
# Out:
# Name
# Alice       78
# Bob         93
# Charlie    138
# Name: Age, dtype: int64

# %%
data.groupby(['Year', 'Department'])['Age'].sum()
# Out:
# Year  Department
# 1990  Admin         45
#       HR            25
#       RD            30
# 1991  Admin         46
#       HR            26
#       RD            31
# 1992  Admin         47
#       HR            27
#       RD            32
# Name: Age, dtype: int64
